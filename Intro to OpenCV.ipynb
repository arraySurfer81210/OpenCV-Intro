# %%
import cv2

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
cv2.__version__
# Out:
# '4.0.1'

# %%
img = cv2.imread("dog.jpg")
img
# Out:
# array([[[ 80, 113, 128],
#         [ 73, 106, 121],
#         [ 67,  99, 112],
#         ...,
#         [ 31,  27,  39],
#         [ 27,  31,  42],
#         [ 28,  32,  43]],
#
#        [[ 80, 115, 129],
#         [ 73, 108, 121],
#         [ 68, 102, 115],
#         ...,
#         [ 32,  32,  44],
#         [ 32,  36,  47],
#         [ 32,  36,  47]],
#
#        [[ 77, 114, 128],
#         [ 72, 110, 122],
#         [ 69, 105, 115],
#         ...,
#         [ 35,  39,  50],
#         [ 25,  34,  44],
#         [ 25,  34,  44]],
#
#        ...,
#
#        [[ 96, 170, 164],
#         [ 92, 166, 160],
#         [ 90, 162, 156],
#         ...,
#         [ 57, 124, 117],
#         [ 49, 125, 113],
#         [ 50, 126, 114]],
#
#        [[ 96, 170, 164],
#         [ 92, 166, 160],
#         [ 91, 163, 157],
#         ...,
#         [ 53, 120, 113],
#         [ 49, 125, 113],
#         [ 50, 126, 114]],
#
#        [[ 97, 171, 165],
#         [ 92, 166, 160],
#         [ 91, 163, 157],
#         ...,
#         [ 65, 132, 125],
#         [ 49, 125, 113],
#         [ 50, 126, 114]]], dtype=uint8)

# %%
cv2.imshow("Dog Image", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread("dog.jpg", 0)
cv2.imshow("Dog Image", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imwrite("saved_dog_image.jpg", img)
# Out:
# True

# %%
cv2.imwrite("saved_dog_image.jpg", img)
# Out:
# True

# %%
hsv_img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
cv2.imshow("HSV Dog Image", hsv_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-10-a7559b3e4b64> in <module>
# ----> 1 hsv_img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
#       2 cv2.imshow("HSV Dog Image", hsv_img)
#       3 cv2.waitKey(0)
#       4 cv2.destroyAllWindows()
#
# error: OpenCV(4.0.1) c:\ci\opencv-suite_1573470242804\work\modules\imgproc\src\color.hpp:259: error: (-2:Unspecified error) in function '__cdecl cv::CvtHelper<struct cv::Set<3,4,-1>,struct cv::Set<3,-1,-1>,struct cv::Set<0,5,-1>,2>::CvtHelper(const class cv::_InputArray &,const class cv::_OutputArray &,int)'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1

# %% [markdown]
# # Drawing with CV2

# %%
cv2.line(img, (0,0), (400, 400), (255,0,0), 5)
cv2.imshow("Line on Dog", img)
cv2.waitKey(0)

# %%
plt.imshow(img)

# %%
cv2.circle(img, (100,50), 10, (255,0,0), 5)
cv2.imshow("Circle on Dog", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.putText(img, "A Dog", (50,200), cv2.FONT_HERSHEY_COMPLEX,1,(0,255,0), 5)
plt.imshow(img)

# %% [markdown]
# # CallBack and Trackbars

# %%
black_img = np.zeros((512,512,3), np.uint8)
cv2.namedWindow("Black Image")

def draw_circle(event, x, y, flags, param):
    if event == cv2.EVENT_LBUTTONDOWN:
        cv2.circle(black_img, (x,y), 50, (255,50,70),5)
        
cv2.setMouseCallback('Black Image', draw_circle)

while(1):
    cv2.imshow('Black Image', black_img)
    k = cv2.waitKey(5)
    if k == 27:
        break
cv2.destroyAllWindows()

# %%
cv2.namedWindow('Image')

cv2.createTrackbar('Channel','Image', 0,2,lambda x:print(x))

while(1):
    cv2.imshow('Image', img[:,:,v])
    v = cv2.getTrackbarPos('Channel', 'Image')
    
    k = cv2.waitKey(5)
    if k == 27:
        break
        
cv2.destroyAllWindows()

# %% [markdown]
# ## Basic Image Operations

# %%
px = img[100, 150]
px
# Out:
# array([145, 212, 227], dtype=uint8)

# %%
plt.imshow(img)

# %%
px_blue = img[100,150,0]
px_blue
# Out:
# 145

# %%
b = img[:,:,0]
cv2.imshow('Blue Channel', b)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img.shape
# Out:
# (259, 194, 3)

# %%
#Check the image data type
img.dtype
# Out:
# dtype('uint8')

# %%
# Get total number of pixels by multiplying array
img.size
# Out:
# 150738

# %%
# Manual demo of img size by multiplying array in img.shape
# Will be same as img.size
259*194*3
# Out:
# 150738

# %%
# Get a specific part of the image
face = img[0:120, 20:125]
plt.imshow(face)

# %%
# Split image into BGR channels
b,g,r = cv2.split(img)
cv2.imshow('b', b)
cv2.imshow('g', g)
cv2.imshow('r', r)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Merge the channels 
img = cv2.merge((b,g,r))
cv2.imshow('Image', img)
cv2.waitKey(0)
cv2.destroyAllWindows
# Out:
# <function destroyAllWindows>

# %%
horizontal_stack = np.hstack((img, img))
# Two different images can be combines, but they must be the same shape
